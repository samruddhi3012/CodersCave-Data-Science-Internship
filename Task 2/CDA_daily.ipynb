# %% [markdown]
# # <center> Task 2. Climate Data Analysis </center>

# %% [markdown]
# <u>Normal Task: Climate data Analysis</u>
#
# Dataset : https://www.kaggle.com/datasets/die9origephit/temperature-data-albany-new-york

# %% [markdown]
# Objective: To derive valuable insights from climate data, enabling a better understanding of weather conditions over time.

# %% [markdown]
# ---
# 1. Importing Libraries
# 2. Data cleaning
# 3. Exploratory Data Analysis
# 4. Climate Data Analysis
#
# ---

# %% [markdown]
# ## Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
import warnings
warnings.filterwarnings('ignore')

# %%
daily = pd.read_csv(r'daily_data.csv')

# %%
daily.head(3)
# Out:
#        STATION                 DATE REPORT_TYPE  SOURCE BackupElements  \
# 0  72518014735  2015-01-01T23:59:00       SOD         6         PRECIP
# 1  72518014735  2015-01-02T23:59:00       SOD         6         PRECIP
# 2  72518014735  2015-01-03T23:59:00       SOD         6         PRECIP
#
#    BackupElevation BackupEquipment  BackupLatitude  BackupLongitude  \
# 0              260         PLASTIC         42.6918        -73.83109
# 1              260         PLASTIC         42.6918        -73.83109
# 2              260         PLASTIC         42.6918        -73.83109
#
#        BackupName  ...  DailyPeakWindDirection  DailyPeakWindSpeed  \
# 0  NWS ALBANY, NY  ...                   190.0                26.0
# 1  NWS ALBANY, NY  ...                   250.0                30.0
# 2  NWS ALBANY, NY  ...                   170.0                21.0
#
#    DailyPrecipitation  DailySnowDepth  DailySnowfall  \
# 0                0.00             0.0            0.0
# 1                   T             0.0              T
# 2                0.57             0.0            1.6
#
#    DailySustainedWindDirection  DailySustainedWindSpeed  Sunrise  Sunset  \
# 0                        190.0                     20.0    726.0  1632.0
# 1                        310.0                     23.0    726.0  1633.0
# 2                        160.0                     15.0    726.0  1634.0
#
#    WindEquipmentChangeDate
# 0               2006-09-08
# 1               2006-09-08
# 2               2006-09-08
#
# [3 rows x 32 columns]

# %% [markdown]
# The analysis is performed for Albany (NY) with station 72518014735 with lat = 42.6918, 42.6812 and lon = -73.83109, -73.8165

# %% [markdown]
# ## Data Cleaning

# %%
daily.describe()
# Out:
#             STATION  SOURCE  BackupElevation  BackupLatitude  BackupLongitude  \
# count  2.668000e+03  2668.0           2668.0     2668.000000      2668.000000
# mean   7.251801e+10     6.0            260.0       42.689750       -73.828268
# std    0.000000e+00     0.0              0.0        0.004187         0.005764
# min    7.251801e+10     6.0            260.0       42.681200       -73.831090
# 25%    7.251801e+10     6.0            260.0       42.691800       -73.831090
# 50%    7.251801e+10     6.0            260.0       42.691800       -73.831090
# 75%    7.251801e+10     6.0            260.0       42.691800       -73.831090
# max    7.251801e+10     6.0            260.0       42.691800       -73.816500
#
#        DailyAverageDewPointTemperature  DailyAverageDryBulbTemperature  \
# count                      2668.000000                     2668.000000
# mean                         38.217766                       50.107571
# std                          19.116250                       18.747310
# min                         -19.000000                       -3.000000
# 25%                          24.000000                       35.000000
# 50%                          38.000000                       51.000000
# 75%                          55.000000                       67.000000
# max                          73.000000                       87.000000
#
#        DailyAverageRelativeHumidity  DailyAverageSeaLevelPressure  \
# count                   2668.000000                   2668.000000
# mean                      66.085082                     30.031945
# std                       13.401359                      0.223771
# min                       24.000000                     29.240000
# 25%                       57.000000                     29.880000
# 50%                       66.000000                     30.020000
# 75%                       76.000000                     30.180000
# max                      100.000000                     30.740000
#
#        DailyAverageStationPressure  ...  \
# count                  2668.000000  ...
# mean                     29.709059  ...
# std                       0.220846  ...
# min                      28.890000  ...
# 25%                      29.570000  ...
# 50%                      29.700000  ...
# 75%                      29.850000  ...
# max                      30.420000  ...
#
#        DailyDepartureFromNormalAverageTemperature  DailyHeatingDegreeDays  \
# count                                 2668.000000             2668.000000
# mean                                     2.155660               17.040480
# std                                      8.202932               16.134205
# min                                    -28.700000                0.000000
# 25%                                     -3.200000                0.000000
# 50%                                      1.900000               14.000000
# 75%                                      7.200000               30.000000
# max                                     34.700000               68.000000
#
#        DailyMaximumDryBulbTemperature  DailyMinimumDryBulbTemperature  \
# count                     2668.000000                     2668.000000
# mean                        59.418666                       40.299100
# std                         20.003706                       18.122395
# min                          5.000000                      -13.000000
# 25%                         42.000000                       27.000000
# 50%                         60.000000                       40.000000
# 75%                         77.000000                       55.250000
# max                         97.000000                       77.000000
#
#        DailyPeakWindDirection  DailyPeakWindSpeed  \
# count             2668.000000         2668.000000
# mean               222.387556           25.513493
# std                 90.828564            9.436276
# min                 10.000000            6.000000
# 25%                170.000000           19.000000
# 50%                260.000000           24.000000
# 75%                290.000000           31.000000
# max                360.000000           70.000000
#
#        DailySustainedWindDirection  DailySustainedWindSpeed      Sunrise  \
# count                  2668.000000              2668.000000  2668.000000
# mean                    223.924288                19.023238   563.145427
# std                      90.846564                 6.942113   108.536855
# min                      10.000000                 5.000000   416.000000
# 25%                     170.000000                14.000000   447.000000
# 50%                     270.000000                18.000000   547.000000
# 75%                     290.000000                23.000000   650.000000
# max                     360.000000                67.000000   726.000000
#
#             Sunset
# count  2668.000000
# mean   1783.491004
# std     111.230222
# min    1621.000000
# 25%    1658.000000
# 50%    1805.000000
# 75%    1905.000000
# max    1938.000000
#
# [8 rows x 23 columns]

# %%
daily.isnull().sum()
# Out:
# STATION                                       0
# DATE                                          0
# REPORT_TYPE                                   0
# SOURCE                                        0
# BackupElements                                0
# BackupElevation                               0
# BackupEquipment                               0
# BackupLatitude                                0
# BackupLongitude                               0
# BackupName                                    0
# DailyAverageDewPointTemperature               0
# DailyAverageDryBulbTemperature                0
# DailyAverageRelativeHumidity                  0
# DailyAverageSeaLevelPressure                  0
# DailyAverageStationPressure                   0
# DailyAverageWetBulbTemperature                0
# DailyAverageWindSpeed                         0
# DailyCoolingDegreeDays                        0
# DailyDepartureFromNormalAverageTemperature    0
# DailyHeatingDegreeDays                        0
# DailyMaximumDryBulbTemperature                0
# DailyMinimumDryBulbTemperature                0
# DailyPeakWindDirection                        0
# DailyPeakWindSpeed                            0
# DailyPrecipitation                            0
# DailySnowDepth                                0
# DailySnowfall                                 0
# DailySustainedWindDirection                   0
# DailySustainedWindSpeed                       0
# Sunrise                                       0
# Sunset                                        0
# WindEquipmentChangeDate                       0
# dtype: int64

# %%
daily.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2668 entries, 0 to 2667
# Data columns (total 32 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   STATION                                     2668 non-null   int64
#  1   DATE                                        2668 non-null   object
#  2   REPORT_TYPE                                 2668 non-null   object
#  3   SOURCE                                      2668 non-null   int64
#  4   BackupElements                              2668 non-null   object
#  5   BackupElevation                             2668 non-null   int64
#  6   BackupEquipment                             2668 non-null   object
#  7   BackupLatitude                              2668 non-null   float64
#  8   BackupLongitude                             2668 non-null   float64
#  9   BackupName                                  2668 non-null   object
#  10  DailyAverageDewPointTemperature             2668 non-null   float64
#  11  DailyAverageDryBulbTemperature              2668 non-null   float64
#  12  DailyAverageRelativeHumidity                2668 non-null   float64
#  13  DailyAverageSeaLevelPressure                2668 non-null   float64
#  14  DailyAverageStationPressure                 2668 non-null   float64
#  15  DailyAverageWetBulbTemperature              2668 non-null   float64
#  16  DailyAverageWindSpeed                       2668 non-null   float64
#  17  DailyCoolingDegreeDays                      2668 non-null   float64
#  18  DailyDepartureFromNormalAverageTemperature  2668 non-null   float64
#  19  DailyHeatingDegreeDays                      2668 non-null   float64
#  20  DailyMaximumDryBulbTemperature              2668 non-null   float64
#  21  DailyMinimumDryBulbTemperature              2668 non-null   float64
#  22  DailyPeakWindDirection                      2668 non-null   float64
#  23  DailyPeakWindSpeed                          2668 non-null   float64
#  24  DailyPrecipitation                          2668 non-null   object
#  25  DailySnowDepth                              2668 non-null   object
#  26  DailySnowfall                               2668 non-null   object
#  27  DailySustainedWindDirection                 2668 non-null   float64
#  28  DailySustainedWindSpeed                     2668 non-null   float64
#  29  Sunrise                                     2668 non-null   float64
#  30  Sunset                                      2668 non-null   float64
#  31  WindEquipmentChangeDate                     2668 non-null   object
# dtypes: float64(20), int64(3), object(9)
# memory usage: 667.1+ KB

# %%
# Convert the datatype of date column
daily['DATE'] = pd.to_datetime(daily['DATE'])

# %%
daily.head(3)
# Out:
#        STATION                DATE REPORT_TYPE  SOURCE BackupElements  \
# 0  72518014735 2015-01-01 23:59:00       SOD         6         PRECIP
# 1  72518014735 2015-01-02 23:59:00       SOD         6         PRECIP
# 2  72518014735 2015-01-03 23:59:00       SOD         6         PRECIP
#
#    BackupElevation BackupEquipment  BackupLatitude  BackupLongitude  \
# 0              260         PLASTIC         42.6918        -73.83109
# 1              260         PLASTIC         42.6918        -73.83109
# 2              260         PLASTIC         42.6918        -73.83109
#
#        BackupName  ...  DailyPeakWindDirection  DailyPeakWindSpeed  \
# 0  NWS ALBANY, NY  ...                   190.0                26.0
# 1  NWS ALBANY, NY  ...                   250.0                30.0
# 2  NWS ALBANY, NY  ...                   170.0                21.0
#
#    DailyPrecipitation  DailySnowDepth  DailySnowfall  \
# 0                0.00             0.0            0.0
# 1                   T             0.0              T
# 2                0.57             0.0            1.6
#
#    DailySustainedWindDirection  DailySustainedWindSpeed  Sunrise  Sunset  \
# 0                        190.0                     20.0    726.0  1632.0
# 1                        310.0                     23.0    726.0  1633.0
# 2                        160.0                     15.0    726.0  1634.0
#
#    WindEquipmentChangeDate
# 0               2006-09-08
# 1               2006-09-08
# 2               2006-09-08
#
# [3 rows x 32 columns]

# %% [markdown]
# ## Exploratory data analysis

# %%
# Analyzing the columns
for col in daily.columns:
    unique_values = daily[col].unique()
    nunique_values = daily[col].nunique()
    print(f"Column: {col}")
    print(f"Unique values: {unique_values}")
    print(f"Number of unique values: {nunique_values}")
    print("-----------")
# Out:
# Column: STATION
# Unique values: [72518014735]
# Number of unique values: 1
# -----------
# Column: DATE
# Unique values: <DatetimeArray>
# ['2015-01-01 23:59:00', '2015-01-02 23:59:00', '2015-01-03 23:59:00',
#  '2015-01-04 23:59:00', '2015-01-05 23:59:00', '2015-01-06 23:59:00',
#  '2015-01-07 23:59:00', '2015-01-08 23:59:00', '2015-01-09 23:59:00',
#  '2015-01-10 23:59:00',
#  ...
#  '2022-05-22 23:59:00', '2022-05-23 23:59:00', '2022-05-24 23:59:00',
#  '2022-05-25 23:59:00', '2022-05-26 23:59:00', '2022-05-27 23:59:00',
#  '2022-05-28 23:59:00', '2022-05-29 23:59:00', '2022-05-30 23:59:00',
#  '2022-05-31 23:59:00']
# Length: 2668, dtype: datetime64[ns]
# Number of unique values: 2668
# -----------
# Column: REPORT_TYPE
# Unique values: ['SOD  ']
# Number of unique values: 1
# -----------
# Column: SOURCE
# Unique values: [6]
# Number of unique values: 1
# -----------
# Column: BackupElements
# Unique values: ['PRECIP']
# Number of unique values: 1
# -----------
# Column: BackupElevation
# Unique values: [260]
# Number of unique values: 1
# -----------
# Column: BackupEquipment
# Unique values: ['PLASTIC']
# Number of unique values: 1
# -----------
# Column: BackupLatitude
# Unique values: [42.6918 42.6812]
# Number of unique values: 2
# -----------
# Column: BackupLongitude
# Unique values: [-73.83109 -73.8165 ]
# Number of unique values: 2
# -----------
# Column: BackupName
# Unique values: ['NWS ALBANY, NY']
# Number of unique values: 1
# -----------
# Column: DailyAverageDewPointTemperature
# Unique values: [  7.  17.  18.  35.  11.   5.  -1.  -6.   8.   0.   4.  25.  -2.  -3.
#   -4.  27.  24.   6.  12.  14.  23.   2.   3.  16.  -5.  10.  26.   9.
#   20.  19.  32.  22.   1.  36.  29.  21.  39.  30.  40.  31.  46.  37.
#   38.  41.  50.  56.  63.  62.  55.  54.  33.  51.  65.  60.  52.  49.
#   47.  44.  42.  61.  57.  59.  58.  53.  48.  69.  64.  66.  70.  67.
#   68.  43.  45.  28.  13.  34.  15.  -9. -19.  71.  73.  72. -11.  -8.
#  -10. -13. -14.  -7.]
# Number of unique values: 88
# -----------
# Column: DailyAverageDryBulbTemperature
# Unique values: [25. 32. 27. 39. 13.  9.  7. 20. 12. 18. 15.  5. 21. 11. 34. 24. 16. 28.
#  14. 19. 26. 35. 22. 30. 31. 43. 33. 38. 36. 37. 40. 46. 56. 48. 45. 41.
#  49. 55. 57. 52. 50. 58. 51. 53. 44. 54. 60. 59. 64. 72. 69. 66. 74. 71.
#  75. 76. 70. 65. 63. 79. 78. 73. 68. 77. 67. 81. 80. 82. 62. 61. 42. 47.
#  29. 23.  6. -3.  8. 83. 17.  2.  3.  1.  4. 10. 84. 85. 87. 86. -1.]
# Number of unique values: 89
# -----------
# Column: DailyAverageRelativeHumidity
# Unique values: [ 46.  57.  74.  86.  59.  68.  53.  63.  54.  50.  80.  65.  47.  79.
#   66.  55.  64.  78.  71.  51.  73.  62.  69.  49.  48.  52.  60.  36.
#   38.  81.  58.  33.  34.  40.  90.  67.  70.  44.  56.  42.  30.  45.
#  60. 63. 59. 69. 64. 50. 65. 66. 58. 56. 71. 70. 72. 53.  4. -4. 73. 75.
#  13.  1.  0.  2. 76. 74. -1.]
# Number of unique values: 79
# -----------
# Column: DailyAverageWindSpeed
# Unique values: [ 8.8  9.5  4.3 10.  16.8  5.  12.9  8.6 12.4  7.5  8.   8.5  1.8  3.2
#  11.9  6.   9.7 14.4 10.9  2.   4.8  7.  13.8  8.3  9.1 14.7 14.2  5.3
#  15.1 11.3  9.2  4.1  4.7  6.6  6.9 11.6 16.1  5.7  5.5 15.6  3.4 13.1
#  16.2 10.1  4.9 10.8 15.2 12.3  3.  11.   6.5  9.   4.4 12.2 10.2 16.7
#   4.5  8.1 13.7 13.9 13.3 11.5  7.1  8.9  9.3  7.3  7.4  9.4  8.2  3.3
#   4.6  4.   3.9 12.7  9.8 12.8  2.9 11.4 10.4 14.6 13.2  6.1  9.6 12.1
#  10.6 11.1  2.8 10.3 15.   3.1  7.6  6.8  5.8  5.9  2.4  7.2  1.5  1.9
#   3.5  7.8  5.1  8.4  5.4  6.4  2.6  5.6  6.3  3.7  3.8  2.7  1.6  3.6
#   5.2  6.7  0.8  1.2  7.7  1.1 12.5 13.5  4.2 10.5  7.9  8.7  0.9  2.3
#  14.   1.7 12.   1.3  2.2 11.7 14.5  0.5 16.5 18.7 13.4 12.6  9.9 15.9
#  15.5 18.8 18.4 20.6 17.4 16.3  2.1 11.8 17.3  2.5 16.6 10.7  6.2 11.2
#   1.4 19.2 17.1 16.4 15.8 20.  14.1 15.3 13.6 17.5 14.9 18.  17.8  1.
#  18.3 15.4 19.9 13.  14.3 14.8  0.7 20.5 18.5 19.8 20.4 17.9 17.2  0.6
#  18.6 20.1 17.6 15.7 18.2 17.  19.5  0.3 16.9 16.  17.7]
# Number of unique values: 193
# -----------
# Column: DailyCoolingDegreeDays
# Unique values: [ 0.  7.  4.  1.  9.  6. 10. 11.  5. 14. 13.  8.  3. 12.  2. 16. 15. 17.
#  18. 19. 20. 22. 21.]
# Number of unique values: 23
# -----------
# Column: DailyDepartureFromNormalAverageTemperature
# Unique values: [  1.4   8.6   3.7  15.9   4.1  -9.8 -13.7 -15.5  -2.4 -10.4  -4.3   9.8
#   -7.2 -17.1  -7.1  -1.1 -11.1   9.9  11.9   1.9  -6.2   2.8   2.7   5.6
#    2.5  -8.5  -8.6  -9.7  -9.9  -4.  -16.1 -15.4  -3.6 -10.9   4.8 -16.9
#   -9.2  -1.5  -0.9  10.4   0.1  -2.3   4.3   0.5   2.2 -10.2  -9.6  -8.
#  -11.9 -16.3 -11.7  -5.2   0.  -12.5 -12.9  -1.3  -2.8  13.9  -9.    4.5
#   -7.3  -6.8  -0.2  -4.7   2.9   8.5  10.1   4.7   8.8   9.4   2.   -0.4
#    3.2  -9.5  -1.6   1.7   7.3   3.    5.3  10.   17.7  14.4  11.   10.7
#   18.4  15.1  18.8  19.5  13.2  -3.4   0.3   7.   13.7   7.4   7.2  -8.1
#  '0.51' '0.39' '0.24' '0.19' '0.46' '0.61' '1.29' '0.21' '1.37' '0.62'
#  '0.56' '2.55' '1.13' '1.08' '0.42' '1.21' '1.55' '0.53' '0.71' '1.58'
#  '1.18' '0.95' '0.16' '0.75' '0.80' '1.48' '0.66' '1.12' '0.34' '1.30'
#  '0.74' '1.72' '0.96' '1.06' '0.49' '0.27' '0.63' '0.69' '0.67' '0.88'
#  '1.24' '1.05' '0.44' '0.58' '0.55' '0.97' '1.04' '2.26' '1.25' '1.16'
#  '1.28' '0.43' '0.89' '1.59' '0.81' '0.98' '1.60' '1.63' '0.92' '0.76'
#  '0.99' '0.60' '0.77' '0.84' '0.52' '0.91' '3.92' '1.02' '0.72' '1.03'
#  '1.38' '1.73' '1.54' '1.42' '1.39' '1.65' '0.83' '1.47' '1.17' '1.01'
#  '2.03']
# Number of unique values: 142
# -----------
# Column: DailySnowDepth
# Unique values: ['0.0' '1.0' '2.0' '3.0' '6.0' '4.0' '12.0' '13.0' '11.0' '10.0' '8.0'
#  '5.0' '7.0' '9.0' '15.0' '14.0' '0' '1' '4' '2' '3' 'T' '11' '10' '9' '8'
#  '6' '5' '13' '18' '15' '14' '12' '16' '19' '17' '7']
# Number of unique values: 37
# -----------
# Column: DailySnowfall
# Unique values: ['0.0' 'T' '1.6' '0.5' '1.5' '2.6' '0.1' '0.8' '0.2' '5.6' '1.4' '0.4'
#  '0.6' '1.9' '0.9' '1.3' '0.3' '0.7' '1.1' '2.1' '4.3' '1.7' '2.4' '11.2'
#  '1.0' '7.6' '17.0' '3.4' '5.5' '4.9' '6.2' '1.2' '3.9' '11.9' '8.4' '3.5'
#  '11.5' '3.2' '10.4' '3.6' '4.8' '2.3' '2.9' '1.8' '13.3' '6.8' '2.5'
#  '2.8' '3.0' '6.1' '19.7' '2.7' '4.0' '4.4' '3.7' '6.4' '4.6' '4.2']
# Number of unique values: 58
# -----------
# Column: DailySustainedWindDirection
# Unique values: [190. 310. 160. 290. 200. 170. 300. 280. 180.  10.  90. 360. 330.  20.
#  350. 270. 320. 150.  40. 260. 210.  30.  50. 340. 230. 130.  70. 100.
#  250. 240. 140. 220.  60.  80. 110. 120.]
# Number of unique values: 36
# -----------
# Column: DailySustainedWindSpeed
# Unique values: [20. 23. 15. 24. 32. 13. 33. 21. 26. 16. 18.  8. 10. 31. 29. 28. 14. 37.
#  39. 12. 35. 22. 17. 25. 36.  9. 30.  7.  6. 40. 38. 43. 47. 67.  5. 41.
#  44.]
# Number of unique values: 37
# -----------
# Column: Sunrise
# Unique values: [726. 725. 724. 723. 722. 721. 720. 719. 718. 717. 716. 715. 714. 713.
#  712. 711. 632. 630. 628. 627. 625. 623. 622. 620. 618. 616. 615. 613.
#  611. 610. 608. 606. 604. 603. 601. 559. 557. 556. 554. 552. 550. 549.
#  547. 545. 543. 541. 540. 538. 536. 535. 533. 531. 529. 528. 526. 524.
#  523. 521. 519. 518. 516. 514. 513. 511. 509. 508. 506. 505. 503. 502.
# 1                            32.0                          57.0
#
#    DailyAverageSeaLevelPressure  DailyAverageStationPressure  \
# 0                         29.97                        29.65
# 1                         30.18                        29.80
#
#    DailyAverageWetBulbTemperature  DailyAverageWindSpeed  \
# 0                            21.0                    8.8
# 1                            26.0                    9.5
#
#    DailyCoolingDegreeDays  DailyDepartureFromNormalAverageTemperature  \
# 0                     0.0                                         1.4
# 1                     0.0                                         8.6
#
#    DailyHeatingDegreeDays  DailyMaximumDryBulbTemperature  \
# 0                    40.0                            32.0
# 1                    33.0                            37.0
#
#    DailyMinimumDryBulbTemperature  DailyPeakWindDirection  DailyPeakWindSpeed  \
# 0                            18.0                   190.0                26.0
# 1                            26.0                   250.0                30.0
#
#   DailyPrecipitation DailySnowDepth DailySnowfall  \
# 0               0.00            0.0           0.0
# 1                  T            0.0             T
#
#    DailySustainedWindDirection  DailySustainedWindSpeed
# 0                        190.0                     20.0
# 1                        310.0                     23.0

# %% [markdown]
# The columns that are irrelevant to the analysis are removed for through analysis.

# %%
daily.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2668 entries, 0 to 2667
# Data columns (total 20 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   DATE                                        2668 non-null   datetime64[ns]
#  1   DailyAverageDewPointTemperature             2668 non-null   float64
#  2   DailyAverageDryBulbTemperature              2668 non-null   float64
#  3   DailyAverageRelativeHumidity                2668 non-null   float64
#  4   DailyAverageSeaLevelPressure                2668 non-null   float64
#  5   DailyAverageStationPressure                 2668 non-null   float64
#  6   DailyAverageWetBulbTemperature              2668 non-null   float64
#  7   DailyAverageWindSpeed                       2668 non-null   float64
#  8   DailyCoolingDegreeDays                      2668 non-null   float64
#  9   DailyDepartureFromNormalAverageTemperature  2668 non-null   float64
#  10  DailyHeatingDegreeDays                      2668 non-null   float64
#  11  DailyMaximumDryBulbTemperature              2668 non-null   float64
#  12  DailyMinimumDryBulbTemperature              2668 non-null   float64
#  13  DailyPeakWindDirection                      2668 non-null   float64
#  14  DailyPeakWindSpeed                          2668 non-null   float64
#  15  DailyPrecipitation                          2668 non-null   object
#  16  DailySnowDepth                              2668 non-null   object
#  17  DailySnowfall                               2668 non-null   object
#  18  DailySustainedWindDirection                 2668 non-null   float64
#  19  DailySustainedWindSpeed                     2668 non-null   float64
# dtypes: datetime64[ns](1), float64(16), object(3)
# memory usage: 417.0+ KB

# %%
# Analyzing object dtpye columns
cols = ['DailyPrecipitation', 'DailySnowDepth', 'DailySnowfall']

for i in cols:
    unique_values = daily[i].unique()
    print(f"Column: {i}")
    print(f"Unique values: {unique_values}")
    print("-----------")
# Out:
# Column: DailyPrecipitation
# Unique values: ['0.00' 'T' '0.57' '0.22' '0.05' '0.20' '0.59' '0.06' '0.02' '0.23' '0.18'
#  '0.08' '0.10' '0.03' '0.04' '0.78' '0.09' '0.28' '0.01' '0.35' '0.15'
#  '0.17' '0.11' '0.12' '0.54' '0.26' '0.25' '0.37' '0.64' '0.48' '0.79'
#  '0.50' '1.62' '0.41' '0.14' '0.07' '0.30' '0.90' '1.27' '0.13' '1.84'
#  '0.86' '0.45' '0.65' '1.57' '1.11' '2.74' '0.70' '0.33' '1.20' '0.73'
#  '0.32' '0.47' '0.40' '0.31' '0.87' '0.29' '0.82' '2.00' '0.36' '0.38'
#  '0.51' '0.39' '0.24' '0.19' '0.46' '0.61' '1.29' '0.21' '1.37' '0.62'
#  '0.56' '2.55' '1.13' '1.08' '0.42' '1.21' '1.55' '0.53' '0.71' '1.58'
#  '1.18' '0.95' '0.16' '0.75' '0.80' '1.48' '0.66' '1.12' '0.34' '1.30'
#  '0.74' '1.72' '0.96' '1.06' '0.49' '0.27' '0.63' '0.69' '0.67' '0.88'
#  '1.24' '1.05' '0.44' '0.58' '0.55' '0.97' '1.04' '2.26' '1.25' '1.16'
#  '1.28' '0.43' '0.89' '1.59' '0.81' '0.98' '1.60' '1.63' '0.92' '0.76'
#  '0.99' '0.60' '0.77' '0.84' '0.52' '0.91' '3.92' '1.02' '0.72' '1.03'
#  '1.38' '1.73' '1.54' '1.42' '1.39' '1.65' '0.83' '1.47' '1.17' '1.01'
#  '2.03']
# -----------
# Column: DailySnowDepth
# Unique values: ['0.0' '1.0' '2.0' '3.0' '6.0' '4.0' '12.0' '13.0' '11.0' '10.0' '8.0'
#  '5.0' '7.0' '9.0' '15.0' '14.0' '0' '1' '4' '2' '3' 'T' '11' '10' '9' '8'
#  '6' '5' '13' '18' '15' '14' '12' '16' '19' '17' '7']
# -----------
# Column: DailySnowfall
# Unique values: ['0.0' 'T' '1.6' '0.5' '1.5' '2.6' '0.1' '0.8' '0.2' '5.6' '1.4' '0.4'
#  '0.6' '1.9' '0.9' '1.3' '0.3' '0.7' '1.1' '2.1' '4.3' '1.7' '2.4' '11.2'
#  '1.0' '7.6' '17.0' '3.4' '5.5' '4.9' '6.2' '1.2' '3.9' '11.9' '8.4' '3.5'
#  '11.5' '3.2' '10.4' '3.6' '4.8' '2.3' '2.9' '1.8' '13.3' '6.8' '2.5'
#  '2.8' '3.0' '6.1' '19.7' '2.7' '4.0' '4.4' '3.7' '6.4' '4.6' '4.2']
# -----------

# %% [markdown]
# Here T = trace precipitation amount or snow depth (an amount too small to measure, usually < 0.005 inches water, so replace it with 0.

# %%
cols = ['DailyPrecipitation', 'DailySnowDepth', 'DailySnowfall']

for i in cols:
    if (daily[i] == 'T').any():
        print(f'Column: {i}')
        print(f'Number of values with "T": {(daily[i] == "T").sum()}')
        print("-----------")
# Out:
# Column: DailyPrecipitation
# Number of values with "T": 552
# -----------
# Column: DailySnowDepth
# Number of values with "T": 88
# -----------
# Column: DailySnowfall
# Number of values with "T": 324
# -----------

# %%
# Converting T values to 0.
for i in cols:
    daily[i] = daily[i].replace('T', 0)

# %%
#Correlation between Parameters
plt.figure(figsize=(12,8))
sns.heatmap(daily.corr(), cmap='Blues', annot=True, fmt='.1f', linewidths=.5)
plt.title('Correlation between Parameters', fontsize=14)
plt.xlabel('Parameters')
plt.ylabel('Parameters')
plt.show()

# %% [markdown]
# The two key parameters for anaylysis are :
# 1. Precipitation
# 2. Temperature <br>
#
# From heatmap following parameters are observed to have high correlation with key parameters:<br>
# `Precipitation`:
# 1. Daily Precipitation
# 2. Daily Average Relative Humidity
# 3. DailySnowfall
#
# `Temperature`:
# 1. Daily average dew point temp
# 2. Daily average dry bulb temp
# 3. Daily average wet bulb temp

# %% [markdown]
# # <center> <div style = 'background-color:pink'> Climate Data Analysis </center></div>

# %%
# Convert the data type
daily['DailyPrecipitation'] = daily['DailyPrecipitation'].astype(float)

# %%
plt.figure(figsize=(12, 6))
plt.scatter(daily['DailyAverageDewPointTemperature'],daily['DailyPrecipitation'], alpha=0.5)
plt.title('Daily Precipitation vs. Daily Average Temperature')
plt.xlabel('Daily Average Dew Point Temperature')
plt.ylabel('Daily Precipitation')
plt.show()

# %% [markdown]
# - ## Precipitation Parameters

# %%
# Analysis over parameters associated with precipitation
ppt = daily[['DATE','DailyPrecipitation','DailyAverageRelativeHumidity','DailySnowfall']]
ppt.head(3)
# Out:
#                  DATE  DailyPrecipitation  DailyAverageRelativeHumidity  \
# 0 2015-01-01 23:59:00                0.00                          46.0
# 1 2015-01-02 23:59:00                0.00                          57.0
# 2 2015-01-03 23:59:00                0.57                          74.0
#
#   DailySnowfall
# 0           0.0
# 1             0
# 2           1.6

# %%
ppt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2668 entries, 0 to 2667
# Data columns (total 4 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   DATE                          2668 non-null   datetime64[ns]
#  1   DailyPrecipitation            2668 non-null   float64
#  2   DailyAverageRelativeHumidity  2668 non-null   float64
#  3   DailySnowfall                 2668 non-null   object
# dtypes: datetime64[ns](1), float64(2), object(1)
# memory usage: 83.5+ KB

# %%
# Convert the data type
ppt['DailySnowfall'] = ppt['DailySnowfall'].astype(float)

# %%
ppt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2668 entries, 0 to 2667
# Data columns (total 4 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   DATE                          2668 non-null   datetime64[ns]
#  1   DailyPrecipitation            2668 non-null   float64
#  2   DailyAverageRelativeHumidity  2668 non-null   float64
#  3   DailySnowfall                 2668 non-null   float64
# dtypes: datetime64[ns](1), float64(3)
# memory usage: 83.5 KB

# %%
ppt.describe()
# Out:
#                                 DATE  DailyPrecipitation  \
# count                           2668         2668.000000
# mean   2018-10-01 14:07:27.346326784            0.111166
# min              2015-01-01 23:59:00            0.000000
# 25%              2016-11-29 17:59:00            0.000000
# 50%              2018-10-02 11:59:00            0.000000
# 75%              2020-08-03 05:59:00            0.070000
# max              2022-05-31 23:59:00            3.920000
# std                              NaN            0.273877
#
#        DailyAverageRelativeHumidity  DailySnowfall
# count                   2668.000000    2668.000000
# mean                      66.085082       0.139205
# min                       24.000000       0.000000
# 25%                       57.000000       0.000000
# 50%                       66.000000       0.000000
# 75%                       76.000000       0.000000
# max                      100.000000      19.700000
# std                       13.401359       0.902673

# %% [markdown]
# > #### Anomaly Dectection

# %%
# To identify outliers in data
fig, axs = plt.subplots(1, 3, figsize=(15, 5))
columns = ['DailyPrecipitation', 'DailySnowfall', 'DailyAverageRelativeHumidity']

for i, col in enumerate(columns):
    axs[i].boxplot(ppt[col])
    axs[i].set_xlabel(f'{col}')
    axs[i].set_ylabel('mm or inches' if 'Precipitation' in col or 'Snowfall' in col else 'Percentage')
    axs[i].set_title(f'{col}')

plt.tight_layout()
plt.show()

# %% [markdown]
# Skewness is present in precipitation and snowfall data.

# %% [markdown]
# > #### Daily Trend

# %%
# Daily Trends for Daily Precipitation
years = [2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022]

fig, ax = plt.subplots(4, 2, figsize=(12, 10))
for i, year in enumerate(years):
    data_for_year = ppt[(ppt['DATE'].dt.year == year)]
    ax[i // 2, i % 2].plot(data_for_year['DATE'], data_for_year['DailyPrecipitation'])
    ax[i // 2, i % 2].axhline(data_for_year['DailyPrecipitation'].mean(), color='deeppink', linestyle='-.')
    ax[i // 2, i % 2].set_xlabel('Dates')
    ax[i // 2, i % 2].set_ylabel('Daily Precipitation')
    ax[i // 2, i % 2].set_title(f'Daily Precipitation Plot for {year}')
    ax[i // 2, i % 2].tick_params(axis='y', labelsize=7)

plt.tight_layout()
plt.show()

# %%
# Daily Trend for Snowfall
fig, ax = plt.subplots(4, 2, figsize=(12, 10))
for i, year in enumerate(years):
    data_for_year = ppt[(ppt['DATE'].dt.year == year)]
    ax[i // 2, i % 2].plot(data_for_year['DATE'], data_for_year['DailyAverageRelativeHumidity'])
    ax[i // 2, i % 2].axhline(data_for_year['DailyAverageRelativeHumidity'].mean(), color='deeppink', linestyle='-.')
    ax[i // 2, i % 2].set_xlabel('Dates')
    ax[i // 2, i % 2].set_ylabel('Relavtive Humidity')
    ax[i // 2, i % 2].set_title(f'{year}')
    ax[i // 2, i % 2].tick_params(axis='y', labelsize=7)

plt.suptitle('Daily Average Relative Humidity Plot',fontsize=14)
plt.tight_layout()
plt.show()

# %% [markdown]
# > #### Yearly Distribution

# %%
# Yearly Data
yearly_data = ppt.groupby(ppt['DATE'].dt.year)[['DailyPrecipitation','DailySnowfall','DailyAverageRelativeHumidity']].agg(
    {'DailyPrecipitation':'sum',
     'DailySnowfall':'sum',
     'DailyAverageRelativeHumidity' :'mean'}).reset_index()

# %%
yearly_data
# Out:
#    DATE  DailyPrecipitation  DailySnowfall  DailyAverageRelativeHumidity
# 0  2015               36.50           23.0                     63.279762
# 1  2016               33.15           29.1                     63.534435
# 2  2017               39.94           58.4                     65.931129
# 3  2018               44.28           78.9                     66.071625
# 4  2019               46.05           71.5                     63.698061
# 5  2020               37.06           46.9                     67.191257
# 6  2021               45.36           32.7                     74.194521
# 7  2022               14.25           30.9                     62.284768

# %%
fig,(ax1, ax2) = plt.subplots(1,2,figsize=(11,4))

width = 0.25  
ax1.bar(yearly_data['DATE'] - width/2, yearly_data['DailyPrecipitation'], width, label='Precipitation')
ax1.bar(yearly_data['DATE'] + width/2, yearly_data['DailySnowfall'], width, label='Snowfall')
ax1.set_title('Precipitation and Snowfall')  
ax1.set_xlabel('Years')
ax1.set_ylabel('Mean Daily Average Values')
ax1.legend()

ax2.bar(yearly_data['DATE'], yearly_data['DailyAverageRelativeHumidity'], width = 0.3, label='Relative Humidity')
ax2.set_title('Relative Humidity')  
ax2.set_xlabel('Years')
ax2.set_ylabel('Average Relavtive Humidity (%)')
ax2.legend()

plt.suptitle('Yearly Distribution', fontsize=14)
plt.tight_layout(pad=1)
plt.show()

# %% [markdown]
# Maximum Snowfall is observed in year 2018, following 2019 and then 2017. <br> Maximum Precipitation was observed in 2019,2021 and 2018.<br> Similarly Maximum Average Relative Humidity was obserd in 2021, 2020 and 2018. <br> From above observation it is clear that during 2018 Albany experinced heavy snowfall and precipitation.

# %% [markdown]
# > #### Percentage Changes

# %%
# Percentage change from previous year
yearly_data['Precipitation_Change']     = yearly_data['DailyPrecipitation'].pct_change()*100
yearly_data['RelavtiveHumidity_Change'] = yearly_data['DailyAverageRelativeHumidity'].pct_change()*100
yearly_data['Snowfall_Change']          = yearly_data['DailySnowfall'].pct_change()*100

# %%
yearly_data
# Out:
#    DATE  DailyPrecipitation  DailySnowfall  DailyAverageRelativeHumidity  \
# 0  2015               36.50           23.0                     63.279762
# 1  2016               33.15           29.1                     63.534435
# 2  2017               39.94           58.4                     65.931129
# 3  2018               44.28           78.9                     66.071625
# 4  2019               46.05           71.5                     63.698061
# 5  2020               37.06           46.9                     67.191257
# 6  2021               45.36           32.7                     74.194521
# 7  2022               14.25           30.9                     62.284768
#
#    Precipitation_Change  RelavtiveHumidity_Change  Snowfall_Change
# 0                   NaN                       NaN              NaN
# 1             -9.178082                  0.402456        26.521739
# 2             20.482655                  3.772276       100.687285
# 3             10.866299                  0.213095        35.102740
# 4              3.997290                 -3.592411        -9.378961
# 5            -19.522258                  5.483991       -34.405594
# 6             22.396114                 10.422879       -30.277186
# 7            -68.584656                -16.052065        -5.504587

# %%
# Percentage Change from 2015 to 2022

data_2015 = yearly_data[yearly_data['DATE'] == 2015]
data_2022 = yearly_data[yearly_data['DATE'] == 2022]

print('Changes in precipitation from 2015 to 2022:',((data_2022['DailyPrecipitation'].values - data_2015['DailyPrecipitation'].values)
                                                        / data_2015['DailyPrecipitation'].values) * 100)
print('Changes in relative humidity from 2015 to 2022:',((data_2022['DailyAverageRelativeHumidity'].values - data_2015['DailyAverageRelativeHumidity'].values) 
                                                            / data_2015['DailyAverageRelativeHumidity'].values) * 100)
print('Changes in snowfall from 2015 to 2022:',((data_2022['DailySnowfall'].values - data_2015['DailySnowfall'].values) 
                                                     / data_2015['DailySnowfall'].values) * 100)
# Out:
# Changes in precipitation from 2015 to 2022: [-60.95890411]
# Changes in relative humidity from 2015 to 2022: [-1.57237269]
# Changes in snowfall from 2015 to 2022: [34.34782609]

# %% [markdown]
# - ## Temperature Parameters

# %%
#4. % Changes in  temp from 2015 to 2022.
temp = daily[['DATE','DailyAverageDewPointTemperature', 'DailyAverageDryBulbTemperature','DailyAverageWetBulbTemperature']]

# %%
temp.head(3)
# Out:
#                  DATE  DailyAverageDewPointTemperature  \
# 0 2015-01-01 23:59:00                              7.0
# 1 2015-01-02 23:59:00                             17.0
# 2 2015-01-03 23:59:00                             18.0
#
#    DailyAverageDryBulbTemperature  DailyAverageWetBulbTemperature
# 0                            25.0                            21.0
# 1                            32.0                            26.0
# 2                            27.0                            23.0

# %%
temp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2668 entries, 0 to 2667
# Data columns (total 4 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   DATE                             2668 non-null   datetime64[ns]
#  1   DailyAverageDewPointTemperature  2668 non-null   float64
#  2   DailyAverageDryBulbTemperature   2668 non-null   float64
#  3   DailyAverageWetBulbTemperature   2668 non-null   float64
# dtypes: datetime64[ns](1), float64(3)
# memory usage: 83.5 KB

# %% [markdown]
# > #### Anomaly Detection

# %%
# To identify outliers in data
fig, axs = plt.subplots(1, 3, figsize=(15, 5))
columns = ['DailyAverageDewPointTemperature', 'DailyAverageDryBulbTemperature', 'DailyAverageWetBulbTemperature']

for i, col in enumerate(columns):
    axs[i].boxplot(temp[col])
    axs[i].set_xlabel(f'{col}')
    #axs[i].set_ylabel('mm or inches' if 'Precipitation' in col or 'Snowfall' in col else 'Percentage')
    axs[i].set_title(f'{col}')

plt.tight_layout()
plt.show()

# %% [markdown]
# No skew is present in temperature parameters.

# %% [markdown]
# > #### Seasonal Variation in temperature

# %% [markdown]
# Seasons in New York area :
# 1. Winter : DJF
# 2. Spring : MAM
# 3. Summer : JJA
# 4. Autumn : SON

# %%
# Create a column season
temp['Season'] = temp['DATE'].dt.month.map({12: 'Winter', 1: 'Winter', 2: 'Winter', 
                                            3: 'Spring', 4: 'Spring', 5: 'Spring',
                                            6: 'Summer', 7: 'Summer', 8: 'Summer', 
                                            9: 'Fall', 10: 'Fall', 11: 'Fall'})

temp.head(3)
# Out:
#                  DATE  DailyAverageDewPointTemperature  \
# 0 2015-01-01 23:59:00                              7.0
# 1 2015-01-02 23:59:00                             17.0
# 2 2015-01-03 23:59:00                             18.0
#
#    DailyAverageDryBulbTemperature  DailyAverageWetBulbTemperature  Season
# 0                            25.0                            21.0  Winter
# 1                            32.0                            26.0  Winter
# 2                            27.0                            23.0  Winter

# %%
# Create new 'Year' column
temp['Year'] = temp['DATE'].dt.year

# %%
temp.head()
# Out:
#                  DATE  DailyAverageDewPointTemperature  \
# 0 2015-01-01 23:59:00                              7.0
# 1 2015-01-02 23:59:00                             17.0
# 2 2015-01-03 23:59:00                             18.0
# 3 2015-01-04 23:59:00                             35.0
# 4 2015-01-05 23:59:00                             11.0
#
#    DailyAverageDryBulbTemperature  DailyAverageWetBulbTemperature  Season  \
# 0                            25.0                            21.0  Winter
# 1                            32.0                            26.0  Winter
# 2                            27.0                            23.0  Winter
# 3                            39.0                            38.0  Winter
# 4                            27.0                            20.0  Winter
#
#    Year
# 0  2015
# 1  2015
# 2  2015
# 3  2015
# 4  2015

# %%
grouped_by_year_season = temp.groupby(['Year','Season'])
grouped_by_year_season

# %%
unique_years = temp['Year'].unique()

fig, axs = plt.subplots(4, 2, figsize=(15, 8))
axs = axs.flatten()

for i, year in enumerate(unique_years):
 for season, data in grouped_by_year_season:
     if year in data['Year'].values:
         axs[i].plot(data[data['Year'] == year]['DATE'], data[data['Year'] == year]['DailyAverageDewPointTemperature'], label=season)
 axs[i].set_xlabel('Date')
 axs[i].set_ylabel('Dew Point Temperature')
 axs[i].set_title(f'Seasonal Variation - Year {year}')
 #axs[i].legend(loc="lower left")

plt.tight_layout()
plt.show()

# %% [markdown]
# > #### Percentage changes

# %%
temp.head()
# Out:
#                  DATE  DailyAverageDewPointTemperature  \
# 0 2015-01-01 23:59:00                              7.0
# 1 2015-01-02 23:59:00                             17.0
# 2 2015-01-03 23:59:00                             18.0
# 3 2015-01-04 23:59:00                             35.0
# 4 2015-01-05 23:59:00                             11.0
#
#    DailyAverageDryBulbTemperature  DailyAverageWetBulbTemperature  Season  \
# 0                            25.0                            21.0  Winter
# 1                            32.0                            26.0  Winter
# 2                            27.0                            23.0  Winter
# 3                            39.0                            38.0  Winter
# 4                            27.0                            20.0  Winter
#
#    Year
# 0  2015
# 1  2015
# 2  2015
# 3  2015
# 4  2015

# %%
temp_yearly_data = temp.groupby(temp['DATE'].dt.year)[['DailyAverageDewPointTemperature','DailyAverageDryBulbTemperature',
                                               'DailyAverageWetBulbTemperature']].mean().reset_index()

# %%
temp_yearly_data.head()
# Out:
#    DATE  DailyAverageDewPointTemperature  DailyAverageDryBulbTemperature  \
# 0  2015                        39.869048                       52.970238
# 1  2016                        38.217631                       51.322314
# 2  2017                        38.749311                       50.575758
# 3  2018                        38.652893                       50.429752
# 4  2019                        37.213296                       49.886427
#
#    DailyAverageWetBulbTemperature
# 0                       46.735119
# 1                       45.253444
# 2                       45.126722
# 3                       45.033058
# 4                       44.144044

# %%
# Percentage change from previous year
temp_yearly_data['DewPoint_Change'] = temp_yearly_data['DailyAverageDewPointTemperature'].pct_change()*100
temp_yearly_data['DryBulb_Change']  = temp_yearly_data['DailyAverageDryBulbTemperature'].pct_change()*100
temp_yearly_data['WetBulb_Change']  = temp_yearly_data['DailyAverageWetBulbTemperature'].pct_change()*100

# %%
temp_yearly_data
# Out:
#    DATE  DailyAverageDewPointTemperature  DailyAverageDryBulbTemperature  \
# 0  2015                        39.869048                       52.970238
# 1  2016                        38.217631                       51.322314
# 2  2017                        38.749311                       50.575758
# 3  2018                        38.652893                       50.429752
# 4  2019                        37.213296                       49.886427
# 5  2020                        39.191257                       50.896175
# 6  2021                        40.493151                       49.290411
# 7  2022                        26.761589                       39.509934
#
#    DailyAverageWetBulbTemperature  DewPoint_Change  DryBulb_Change  \
# 0                       46.735119              NaN             NaN
# 1                       45.253444        -4.142102       -3.111038
# 2                       45.126722         1.391192       -1.454643
# 3                       45.033058        -0.248827       -0.288687
# 4                       44.144044        -3.724420       -1.077391
# 5                       45.469945         5.315198        2.024094
# 6                       45.293151         3.321899       -3.154980
# 7                       34.695364       -33.910825      -19.842556
#
#    WetBulb_Change
# 0             NaN
# 1       -3.170369
# 2       -0.280027
# 3       -0.207558
# 4       -1.974135
# 5        3.003579
# 6       -0.388817
# 7      -23.398210

# %%
# Percentage Change from 2015 to 2022

data_2015 = temp_yearly_data[temp_yearly_data['DATE'] == 2015]
data_2022 = temp_yearly_data[temp_yearly_data['DATE'] == 2022]

print('Changes in precipitation from 2015 to 2022:',((data_2022['DailyAverageDewPointTemperature'].values - data_2015['DailyAverageDewPointTemperature'].values)
                                                        / data_2015['DailyAverageDewPointTemperature'].values) * 100)

print('Changes in relative humidity from 2015 to 2022:',((data_2022['DailyAverageDryBulbTemperature'].values - data_2015['DailyAverageDryBulbTemperature'].values) 
                                                            / data_2015['DailyAverageDryBulbTemperature'].values) * 100)

print('Changes in snowfall from 2015 to 2022:',((data_2022['DailyAverageWetBulbTemperature'].values - data_2015['DailyAverageWetBulbTemperature'].values) 
                                                     / data_2015['DailyAverageWetBulbTemperature'].values) * 100)
# Out:
# Changes in precipitation from 2015 to 2022: [-32.8762762]
# Changes in relative humidity from 2015 to 2022: [-25.41107007]
# Changes in snowfall from 2015 to 2022: [-25.7616864]
